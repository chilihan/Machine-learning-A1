# %% [markdown]
# A1:
# ENGG*6500 A1
# Train a MLP on the StumbleUpon Evergreen dataset

# %%
run A1.py
# Out:
# NUM input dimensions: 36
# Before training
# train accuracy: 0.4860
# train cross entropy: 2.1885
# test accuracy: 0.5078
# test cross entropy: 2.1391
# Epoch 0
# Training set cost: 2.18846
# Test set cost:     2.1391
# Epoch 1
# Training set cost: 2.12357
# Test set cost:     2.07661
# Epoch 2
# Training set cost: 2.05975
# Test set cost:     2.01515
# Epoch 3
# Training set cost: 1.99708
# Test set cost:     1.95481
# Epoch 4
# Training set cost: 1.93568
# Test set cost:     1.89568
# Epoch 5
# Training set cost: 1.87562
# Test set cost:     1.83785
# Epoch 6
# Training set cost: 1.817
# Test set cost:     1.78141
# Epoch 7
# Training set cost: 1.75991
# Test set cost:     1.72646
# Epoch 8
# Training set cost: 1.70444
# Test set cost:     1.67307
# Epoch 9
# Training set cost: 1.65068
# Test set cost:     1.62133
# Epoch 10
# Training set cost: 1.59871
# Test set cost:     1.57131
# Epoch 11
# Training set cost: 1.54859
# Test set cost:     1.5231
# Epoch 12
# ...
